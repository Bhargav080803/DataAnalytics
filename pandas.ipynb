# %%
import pandas as pd
import numpy as np
list1 = ['a','b','c','d']
data = np.array(list1)
s=pd.Series(data,index=['c','a','d','b'])
print("numpy data reprentation\n",data,"\n")
print("pandas data reprentation\n",s,"\n")
print(s['d'])
# Out:
# numpy data reprentation
#  ['a' 'b' 'c' 'd']
#
# pandas data reprentation
#  c    a
# a    b
# d    c
# b    d
# dtype: object
#
# c

# %%
l1=pd.Series({'a':1,'b':2,'c':3,'d':4},index=['c','a','d','b'])
print("reprentation \n",l1)

# %%
import pandas as pd
list={'a','b','c','d'}
data=np.array(list)
print(data)
s=pd.Series({'a':0.,'b':3.,'c':2.,'d':10.},index=['a','b','c','d'])
print(s)
# Out:
# {'c', 'b', 'd', 'a'}
# a     0.0
# b     3.0
# c     2.0
# d    10.0
# dtype: float64

# %%
import pandas as pd
data ={'a':0.,'b':3.,'c':2.,'d':10.}
s=pd.Series(data,index=['a','b','c','d'])
print (s)
#"""index order is persisted and the missing element is filled with not a number"""
# Out:
# a     0.0
# b     3.0
# c     2.0
# d    10.0
# dtype: float64
